# %%
import os
import time # for epochs timing in the training loop
import random # for shuffling the training data in the training loop
from pathlib import path # for project directory folders and files
import numpy as np
import pandas as pd
